# %%
#Modulos
import pandas as pd
import numpy as np
import scipy
from math import sqrt 
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn import datasets

# %%
#Estimadores
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
#Metricas de Modelos
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import cohen_kappa_score

# %%
#Cross Validation
from sklearn.model_selection import train_test_split

# %%
#Modulos
import math

# %%
CreditOne_Clasification = pd.read_csv('default of credit card clients.csv', header =1)
CreditOne_Clasification.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ...

# %%
CreditOne_Clasification.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
pd.isnull(CreditOne_Clasification).sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default_payment_next_month    0
# dtype: int64

# %%
CreditOne_Clasification.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
valores_age = [-math.inf, 18, 30, 50, 63, math.inf]

# %%
categorias_age = ["Joven","Adulto_joven","Adulto","Adulto_Avanzado","Adulto_mayor"]

# %%
CreditOne_Clasification['Tipo_Edad']= pd.cut(x=CreditOne_Clasification['AGE'],bins=valores_age, labels=categorias_age)

# %%
CreditOne_Clasification
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
CreditOne_Clasification.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  category
#  3   EDUCATION                   30000 non-null  category
#  4   MARRIAGE                    30000 non-null  category
#  5   Tipos_Edades                30000 non-null  int32
#  6   AGE                         30000 non-null  int64
#  7   PAY_0                       30000 non-null  int64
#  8   PAY_2                       30000 non-null  int64
#  9   PAY_3                       30000 non-null  int64
#  10  PAY_4                       30000 non-null  int64
#  11  PAY_5                       30000 non-null  int64
#  12  PAY_6                       30000 non-null  int64
# ...

# %% [markdown]
# Convertir la variable Tipo_Edad a Factores

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
CreditOne_Clasification['Tipos_Edades']=encoder.fit_transform(CreditOne_Clasification.Tipo_Edad.values)

# %%
CreditOne_Clasification
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
CreditOne_Clasification.LIMIT_BAL.describe()
# Out:
# count      30000.000000
# mean      167484.322667
# std       129747.661567
# min        10000.000000
# 25%        50000.000000
# 50%       140000.000000
# 75%       240000.000000
# max      1000000.000000
# Name: LIMIT_BAL, dtype: float64

# %%
CreditOne_Clasification["SEX"] = CreditOne_Clasification["SEX"].astype("category")
CreditOne_Clasification["EDUCATION"] = CreditOne_Clasification["EDUCATION"].astype("category")
CreditOne_Clasification["MARRIAGE"] = CreditOne_Clasification["MARRIAGE"].astype("category")
CreditOne_Clasification["default_payment_next_month"] = CreditOne_Clasification["default_payment_next_month"].astype("category")
CreditOne_Clasification["Tipos_Edades"] = CreditOne_Clasification["Tipos_Edades"].astype("category")

# %%
CreditOne_Clasification = CreditOne_Clasification[['ID','LIMIT_BAL','SEX','EDUCATION','MARRIAGE','Tipos_Edades','AGE',
                                                   'PAY_0','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6','BILL_AMT1','BILL_AMT2',
                                                   'BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6','PAY_AMT1','PAY_AMT2',
                                                   'PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6','Tipo_Edad',
                                                   'default_payment_next_month']]

# %%
CreditOne_Clasification = CreditOne_Clasification.drop(columns =["AGE","Tipo_Edad"])

# %%
CreditOne_Clasification.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  category
#  3   EDUCATION                   30000 non-null  category
#  4   MARRIAGE                    30000 non-null  category
#  5   Tipos_Edades                30000 non-null  category
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
CreditOne_Clasification.Tipos_Edades.describe()
# Out:
# count     30000
# unique        4
# top           0
# freq      16718
# Name: Tipos_Edades, dtype: int64

# %% [markdown]
# Construicción y evaluación de modelos

# %% [markdown]
#  Features

# %%
features = CreditOne_Clasification.iloc[:,1:24]
print('Summary of feature sample')
features.head()
# Out:
# Summary of feature sample
#    LIMIT_BAL SEX EDUCATION MARRIAGE Tipos_Edades  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000   2         2        1            2      2      2     -1     -1
# 1     120000   2         2        2            2     -1      2      0      0
# 2      90000   2         2        2            0      0      0      0      0
# 3      50000   2         2        1            0      0      0      0      0
# 4      50000   1         2        1            1     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -2  ...        689          0          0          0         0       689
# 1      0  ...       2682       3272       3455       3261         0      1000
# 2      0  ...      13559      14331      14948      15549      1518      1500
# 3      0  ...      49291      28314      28959      29547      2000      2019
# 4      0  ...      35835      20940      19146      19131      2000     36681
#
# ...

# %% [markdown]
# Dependent variable

# %%
depVar = CreditOne_Clasification['default_payment_next_month']

# %% [markdown]
# Training Set 70% (Feature Space: X Training)

# %% [markdown]
# Feature Training Set

# %%
X_train, X_test, y_train, y_test = train_test_split(features, depVar, test_size=0.30, random_state=5)

# %%
#Doble Check
X_train.shape, X_test.shape
# Out:
# ((21000, 23), (9000, 23))

# %% [markdown]
# Modelos

# %%
#Modelos 
modelDTC = DecisionTreeClassifier()
modelrfc = RandomForestClassifier()
modelKNC = KNeighborsClassifier()
modelSVC = SVC()

# %%
modelDTC.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
modelrfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
modelKNC.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
modelSVC.fit(X_train,y_train)
# Out:
# SVC()

# %% [markdown]
# Kappa de Cohen (κ)
#
# Si K es cero, ello significa que la concordancia observada coincide con la que ocurriría por puro azar. Valores positivos señalan mayor concordancia que la que se esperaría por el puro azar. Si el resultado fuera 1, se trataría de una concordancia perfecta. Si K toma un valor negativo, significa existencia de discordancia, que solamente en la tabla de 2*2, podría llegar hasta -1, lo que señalaría una discordancia total entre las dos clasificaciones o evaluaciones.

# %% [markdown]
# Medir el modelo entrenado

# %% [markdown]
# Metricas Modelo Decision Tree Classifier

# %%
predictionsDTC = modelDTC.predict(X_test)
print (accuracy_score(y_test,predictionsDTC))
print (confusion_matrix(y_test,predictionsDTC))
print (cohen_kappa_score(y_test,predictionsDTC))
# Out:
# 0.728
# [[5700 1263]
#  [1185  852]]
# 0.2337092790669284

# %% [markdown]
# Metricas Modelo Random Forest Classifier

# %%
predictionsrfc = modelrfc.predict(X_test)
print (accuracy_score(y_test,predictionsrfc))
print (confusion_matrix(y_test,predictionsrfc))
print (cohen_kappa_score(y_test,predictionsrfc))
# Out:
# 0.8094444444444444
# [[6542  421]
#  [1294  743]]
# 0.3586617683134786

# %% [markdown]
# Metricas Modelo KNeighbors Classifier

# %%
predictionsKNC = modelKNC.predict(X_test)
print (accuracy_score(y_test,predictionsKNC))
print (confusion_matrix(y_test,predictionsKNC))
print (cohen_kappa_score(y_test,predictionsKNC))
# Out:
# 0.7526666666666667
# [[6424  539]
#  [1687  350]]
# 0.11791954760553058

# %% [markdown]
# Metricas Modelo SVC

# %%
predictionsSVC = modelSVC.predict(X_test)
print (accuracy_score(y_test,predictionsSVC))
print (confusion_matrix(y_test,predictionsSVC))
print (cohen_kappa_score(y_test,predictionsSVC))
# Out:
# 0.7736666666666666
# [[6963    0]
#  [2037    0]]
# 0.0

# %% [markdown]
# Modelo de Predicción Seleccionada

# %%
predictionsrfc
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
DFpred = pd.DataFrame(predictionsrfc)
DFpred = DFpred.reset_index()
DFpred
# Out:
#       index  0
# 0         0  0
# 1         1  0
# 2         2  0
# 3         3  0
# 4         4  0
# ...     ... ..
# 8995   8995  0
# 8996   8996  1
# 8997   8997  0
# 8998   8998  0
# 8999   8999  0
#
# [9000 rows x 2 columns]

# %%
X_test
# Out:
#        LIMIT_BAL SEX EDUCATION MARRIAGE Tipos_Edades  PAY_0  PAY_2  PAY_3  \
# 8033       50000   1         2        2            2      0      0     -1
# 29952     210000   1         2        2            2     -1     -1     -1
# 2736       50000   2         2        1            2      0      0      0
# 29677      20000   1         2        2            0      0      0     -2
# 3285      280000   1         1        1            0      0      0      0
# ...          ...  ..       ...      ...          ...    ...    ...    ...
# 29701     240000   1         2        1            0      2      0     -1
# 7535      110000   1         2        2            0      2      2      2
# 7147      140000   2         2        1            0      0     -1     -1
# 5395      490000   2         2        1            1     -1     -1     -1
# 25413      50000   2         2        1            2      0      0      0
#
#        PAY_4  PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ...

# %%
DFx_test = pd.DataFrame(X_test)
DFx_test = DFx_test.reset_index()
DFx_test
# Out:
#       index  LIMIT_BAL SEX EDUCATION MARRIAGE Tipos_Edades  PAY_0  PAY_2  \
# 0      8033      50000   1         2        2            2      0      0
# 1     29952     210000   1         2        2            2     -1     -1
# 2      2736      50000   2         2        1            2      0      0
# 3     29677      20000   1         2        2            0      0      0
# 4      3285     280000   1         1        1            0      0      0
# ...     ...        ...  ..       ...      ...          ...    ...    ...
# 8995  29701     240000   1         2        1            0      2      0
# 8996   7535     110000   1         2        2            0      2      2
# 8997   7147     140000   2         2        1            0      0     -1
# 8998   5395     490000   2         2        1            1     -1     -1
# 8999  25413      50000   2         2        1            2      0      0
#
#       PAY_3  PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# ...

# %%
DFx_test = DFx_test.rename(columns={'index':'No_Test'})
DFx_test
# Out:
#       No_Test  LIMIT_BAL SEX EDUCATION MARRIAGE Tipos_Edades  PAY_0  PAY_2  \
# 0        8033      50000   1         2        2            2      0      0
# 1       29952     210000   1         2        2            2     -1     -1
# 2        2736      50000   2         2        1            2      0      0
# 3       29677      20000   1         2        2            0      0      0
# 4        3285     280000   1         1        1            0      0      0
# ...       ...        ...  ..       ...      ...          ...    ...    ...
# 8995    29701     240000   1         2        1            0      2      0
# 8996     7535     110000   1         2        2            0      2      2
# 8997     7147     140000   2         2        1            0      0     -1
# 8998     5395     490000   2         2        1            1     -1     -1
# 8999    25413      50000   2         2        1            2      0      0
#
# ...

# %%
DFPredicted = pd.concat([DFx_test,DFpred], axis=1)

# %%
DFPredicted
# Out:
#       No_Test  LIMIT_BAL SEX EDUCATION MARRIAGE Tipos_Edades  PAY_0  PAY_2  \
# 0        8033      50000   1         2        2            2      0      0
# 1       29952     210000   1         2        2            2     -1     -1
# 2        2736      50000   2         2        1            2      0      0
# 3       29677      20000   1         2        2            0      0      0
# 4        3285     280000   1         1        1            0      0      0
# ...       ...        ...  ..       ...      ...          ...    ...    ...
# 8995    29701     240000   1         2        1            0      2      0
# 8996     7535     110000   1         2        2            0      2      2
# 8997     7147     140000   2         2        1            0      0     -1
# 8998     5395     490000   2         2        1            1     -1     -1
# 8999    25413      50000   2         2        1            2      0      0
#
# ...

# %%
DFPredicted = DFPredicted.rename(columns={0:'default_payment_next_month_Predicted'})

# %%
DFPredicted = DFPredicted.rename(columns={'index':'No_Predicted'})

# %%
DFPredicted
# Out:
#       No_Test  LIMIT_BAL SEX EDUCATION MARRIAGE Tipos_Edades  PAY_0  PAY_2  \
# 0        8033      50000   1         2        2            2      0      0
# 1       29952     210000   1         2        2            2     -1     -1
# 2        2736      50000   2         2        1            2      0      0
# 3       29677      20000   1         2        2            0      0      0
# 4        3285     280000   1         1        1            0      0      0
# ...       ...        ...  ..       ...      ...          ...    ...    ...
# 8995    29701     240000   1         2        1            0      2      0
# 8996     7535     110000   1         2        2            0      2      2
# 8997     7147     140000   2         2        1            0      0     -1
# 8998     5395     490000   2         2        1            1     -1     -1
# 8999    25413      50000   2         2        1            2      0      0
#
# ...

# %%
DFPredicted = DFPredicted.to_excel("CreditOne Clasificacion_Predicted.xlsx")

# %% [markdown]
# IDENTIFICACION DE FEATURES IMPORTANTES

# %%
model_impfeatures = RandomForestClassifier(n_estimators=10)

# %%
model_impfeatures.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=None, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=1, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, n_estimators=10,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
print(model_impfeatures.feature_importances_)
# Out:
# [0.06682329 0.01277801 0.02365854 0.01601905 0.01886324 0.07369743
#  0.06360616 0.02634309 0.02156196 0.02558485 0.02141026 0.06400516
#  0.05957835 0.05399105 0.05197253 0.05386244 0.05412331 0.0558814
#  0.04750252 0.0478949  0.04467717 0.04543648 0.05072881]

# %%
X_train.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'Tipos_Edades', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'],
#       dtype='object')

# %%
import pandas as pd
feature_importances = pd.DataFrame(model_impfeatures.feature_importances_,
                                   index = ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'Tipos_Edades', 'PAY_0',
       'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'],
                                   columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
#               importance
# PAY_0           0.073697
# LIMIT_BAL       0.066823
# BILL_AMT1       0.064005
# PAY_2           0.063606
# BILL_AMT2       0.059578
# PAY_AMT1        0.055881
# BILL_AMT6       0.054123
# BILL_AMT3       0.053991
# BILL_AMT5       0.053862
# BILL_AMT4       0.051973
# PAY_AMT6        0.050729
# PAY_AMT3        0.047895
# PAY_AMT2        0.047503
# PAY_AMT5        0.045436
# PAY_AMT4        0.044677
# PAY_3           0.026343
# PAY_5           0.025585
# EDUCATION       0.023659
# PAY_4           0.021562
# PAY_6           0.021410
# Tipos_Edades    0.018863
# MARRIAGE        0.016019
# SEX             0.012778

# %%
feature_importances = feature_importances.to_excel("feature_importances.xlsx")
